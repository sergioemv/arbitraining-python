# %%
import requests
import pandas as pd

payment_methods = ["zinli", "wallytech",  "dukascopybank" ]

# Initialize empty DataFrames for asks and bids
all_asks = pd.DataFrame()
all_bids = pd.DataFrame()

url = 'https://2txjwiew8a.execute-api.us-east-1.amazonaws.com/pre/latest/order-book'
params_base = {
    'fiat': 'USD',
    'asset': 'USDT',
}

# %%
import json
for method in payment_methods:
    # Update parameters with the current payment method
    params = params_base.copy()
    params['payment_methods'] = method

    # Sending the GET request
    response = requests.get(url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        print(response.content)
        content_str = response.content.decode('utf-8')
        # Parse the JSON content
        content_data = json.loads(content_str)

        # Create DataFrames for 'asks' and 'bids' and add payment method column
        df_asks = pd.DataFrame(content_data['asks'])
        df_asks['payment_method'] = method

        df_bids = pd.DataFrame(content_data['bids'])
        df_bids['payment_method'] = method

        # Concatenate to the main DataFrames
        all_asks = pd.concat([all_asks, df_asks], ignore_index=True)
        all_bids = pd.concat([all_bids, df_bids], ignore_index=True)
    else:
        print(f"Request failed for payment method {method} with status code:", response.status_code)
# Out:
# b'{"asks": [{"price": "1.001", "available": 828.29, "advertisers": [], "advertisers_qty": 3}, {"price": "1.002", "available": 1668.61, "advertisers": [], "advertisers_qty": 3}, {"price": "1.003", "available": 2627.77, "advertisers": [], "advertisers_qty": 4}, {"price": "1.004", "available": 3399.59, "advertisers": [], "advertisers_qty": 3}, {"price": "1.005", "available": 99.65, "advertisers": [], "advertisers_qty": 1}, {"price": "1.006", "available": 2974.11, "advertisers": [], "advertisers_qty": 4}, {"price": "1.007", "available": 2388.17, "advertisers": [], "advertisers_qty": 6}, {"price": "1.008", "available": 2015.67, "advertisers": [], "advertisers_qty": 4}, {"price": "1.009", "available": 1062.39, "advertisers": [], "advertisers_qty": 2}, {"price": "1.010", "available": 6348.44, "advertisers": [], "advertisers_qty": 6}, {"price": "1.011", "available": 152.65, "advertisers": [], "advertisers_qty": 1}, {"price": "1.012", "available": 2047.65, "advertisers": [], "advertisers_qty": 2}, {"price": "1.014", "available": 101.02, "advertisers": [], "advertisers_qty": 1}, {"price": "1.015", "available": 1847.07, "advertisers": [], "advertisers_qty": 3}, {"price": "1.016", "available": 272.7, "advertisers": [], "advertisers_qty": 2}, {"price": "1.017", "available": 1007.17, "advertisers": [], "advertisers_qty": 1}, {"price": "1.019", "available": 332.99, "advertisers": [], "advertisers_qty": 1}, {"price": "1.020", "available": 1470.01, "advertisers": [], "advertisers_qty": 3}, {"price": "1.023", "available": 2138.56, "advertisers": [], "advertisers_qty": 2}, {"price": "1.027", "available": 100.12, "advertisers": [], "advertisers_qty": 1}, {"price": "1.029", "available": 227.23, "advertisers": [], "advertisers_qty": 1}, {"price": "1.030", "available": 588.56, "advertisers": [], "advertisers_qty": 2}, {"price": "1.031", "available": 228.41, "advertisers": [], "advertisers_qty": 1}, {"price": "1.035", "available": 1312.97, "advertisers": [], "advertisers_qty": 1}, {"price": "1.043", "available": 179.66, "advertisers": [], "advertisers_qty": 1}, {"price": "1.049", "available": 356.12, "advertisers": [], "advertisers_qty": 1}, {"price": "1.050", "available": 99.65, "advertisers": [], "advertisers_qty": 1}, {"price": "1.054", "available": 170.26, "advertisers": [], "advertisers_qty": 1}, {"price": "1.069", "available": 99.72, "advertisers": [], "advertisers_qty": 1}, {"price": "1.070", "available": 110.71, "advertisers": [], "advertisers_qty": 1}, {"price": "1.079", "available": 129.28, "advertisers": [], "advertisers_qty": 1}, {"price": "1.087", "available": 3988.83, "advertisers": [], "advertisers_qty": 1}, {"price": "1.095", "available": 448.9, "advertisers": [], "advertisers_qty": 1}, {"price": "1.098", "available": 904.93, "advertisers": [], "advertisers_qty": 2}], "bids": [{"price": "0.991", "available": 315.0, "advertisers": [], "advertisers_qty": 1}, {"price": "0
0, "advertisers": [], "advertisers_qty": 1}, {"price": "0.902", "available": 160.27, "advertisers": [], "advertisers_qty": 1}, {"price": "0.901", "available": 2000000.0, "advertisers": [], "advertisers_qty": 1}], "market_availability": {"asks": 11160.519999999999, "bids": 2016841.76}, "filters": {"asset": "USDT", "exchange": "binance", "fiat": "USD", "trans_amount": 100, "publisher_type": null, "payment_methods": ["wallytech"], "excepts_payment_methods": [], "with_advertisers": false}}'
# b'{"asks": [{"price": "1.046", "available": 1137.96, "advertisers": [], "advertisers_qty": 3}, {"price": "1.047", "available": 935.7, "advertisers": [], "advertisers_qty": 1}, {"price": "1.059", "available": 394.92, "advertisers": [], "advertisers_qty": 1}, {"price": "1.060", "available": 5060.59, "advertisers": [], "advertisers_qty": 1}, {"price": "1.062", "available": 140.89, "advertisers": [], "advertisers_qty": 1}, {"price": "1.080", "available": 498.6, "advertisers": [], "advertisers_qty": 1}, {"price": "1.087", "available": 3988.83, "advertisers": [], "advertisers_qty": 1}], "bids": [{"price": "1.020", "available": 500.0, "advertisers": [], "advertisers_qty": 1}, {"price": "1.019", "available": 325.0, "advertisers": [], "advertisers_qty": 1}, {"price": "1.018", "available": 3160.85, "advertisers": [], "advertisers_qty": 4}, {"price": "1.017", "available": 1070.0, "advertisers": [], "advertisers_qty": 1}, {"price": "1.016", "available": 1473.0, "advertisers": [], "advertisers_qty": 1}, {"price": "1.015", "available": 500.0, "advertisers": [], "advertisers_qty": 1}, {"price": "1.014", "available": 923.6, "advertisers": [], "advertisers_qty": 2}, {"price": "1.012", "available": 1701.0, "advertisers": [], "advertisers_qty": 1}, {"price": "1.009", "available": 3107.44, "advertisers": [], "advertisers_qty": 1}, {"price": "0.950", "available": 10000.0, "advertisers": [], "advertisers_qty": 1}, {"price": "0.940", "available": 10000.0, "advertisers": [], "advertisers_qty": 1}, {"price": "0.926", "available": 4000.0, "advertisers": [], "advertisers_qty": 1}, {"price": "0.900", "available": 53099.61, "advertisers": [], "advertisers_qty": 2}], "market_availability": {"asks": 12157.490000000002, "bids": 89860.5}, "filters": {"asset": "USDT", "exchange": "binance", "fiat": "USD", "trans_amount": 100, "publisher_type": null, "payment_methods": ["dukascopybank"], "excepts_payment_methods": [], "with_advertisers": false}}'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def abbreviate_number(num):
    """
    Abbreviate a number using 'k', 'M', 'B', etc.
    """
    if num < 1000:
        return str(num)
    for unit in ['k', 'M', 'B', 'T']:
        num /= 1000
        if num < 1000:
            return f"{num:.1f}{unit}"

# Apply the default Seaborn theme
sns.set_theme()

# Count the number of payment methods
num_methods = len(payment_methods)

# Calculate the maximum number of distinct prices across all payment methods
max_prices = max(
    all_asks.groupby('payment_method')['price'].nunique().max(), 
    all_bids.groupby('payment_method')['price'].nunique().max()
)


height_per_subplot = max(6, 0.3 * max_prices) * 1.4  # 40% increase

# Create a figure and a set of subplots with adjusted height
fig, axes = plt.subplots(1, num_methods, figsize=(5 * num_methods, height_per_subplot))

if num_methods == 1:
    axes = [axes]

# Loop through each payment method and create a subplot
for ax, method in zip(axes, payment_methods):
    asks_for_method = all_asks[all_asks['payment_method'] == method].sort_values(by='price', ascending=True)
    bids_for_method = all_bids[all_bids['payment_method'] == method].sort_values(by='price', ascending=True)

    # Plotting asks and bids
    asks_bars = ax.barh(asks_for_method['price'], asks_for_method['available'], color='green', label='Asks')
    bids_bars = ax.barh(bids_for_method['price'], bids_for_method['available'], color='red', label='Bids', alpha=0.7)

    # Add data labels
    for bar in asks_bars + bids_bars:
        width = bar.get_width()
        label = abbreviate_number(width)
        ax.text(width, bar.get_y() + bar.get_height() / 2, f' {label}', va='center')

    # Make the 'available' axis logarithmic
    ax.set_xscale('log')

    # Setting the title
    ax.set_title(f'{method}')

# Add a legend
fig.legend(['Asks', 'Bids'], loc='upper right')

plt.tight_layout()
plt.show()
